# %%
# Imports

import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# %%
X, y = datasets.make_regression(
        n_samples=500, n_features=1, noise=20, random_state=42)

print(f"X Shape:{X.shape}")
print(f"y Shape:{y.shape}")

X_train, y_train = X[:450], y[:450]
X_test, y_test = X[450:], y[450:]

print(f"X train Shape:{X_train.shape}")
print(f"y train Shape:{y_train.shape}")
print(f"X test Shape:{X_test.shape}")
print(f"y test Shape:{y_test.shape}")

plt.figure(figsize=(10,6))
plt.plot(X_train, y_train, 'o', color='blue')
plt.plot(X_test, y_test, 'x', color='red')
plt.grid(True)
# Out:
# X Shape:(500, 1)
# y Shape:(500,)
# X train Shape:(450, 1)
# y train Shape:(450,)
# X test Shape:(50, 1)
# y test Shape:(50,)

# %%
def evaluate(y_test, y_pred):
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Print results
    print(f"Mean Squared Error on Test Set: {mse:.2f}")
    print(f"R-squared (R^2) on Test Set: {r2:.2f}")

# %%
# Implement Linear Regression using sklearn

regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predict values for the test set
y_pred = regressor.predict(X_test)

evaluate(y_test, y_pred)

X_full = np.concatenate((X_train, X_test))
y_pred_line = regressor.predict(X_full)

plt.figure(figsize=(10, 6))

plt.scatter(X_train, y_train, color='blue', label='Training Data', marker='o')
plt.scatter(X_test, y_test, color='red', label='Testing Data', marker='x')
plt.plot(X_full, y_pred_line, color='green', linewidth=2, label='Regression Line')

plt.xlabel("Feature X")
plt.ylabel("Target y")
plt.legend()
plt.grid(True)
# Out:
# Mean Squared Error on Test Set: 371.84
# R-squared (R^2) on Test Set: 0.92

# %%
class Linear_regression():
    def __init__(self, lr = 0.01, n_iter = 1000):
        self.lr = lr
        self.n_iter = n_iter
        self.weight = None
        self.bias = None

    def fit(self, X, y):
        num_samples, num_features = X.shape
        self.weights = np.zeros(num_features)
        self.bias = 0

        for  i in range(self.n_iter):
            y_pred = np.dot(X, self.weights) + self.bias

            dw = (1 / num_samples) * np.dot(X.T, y_pred - y)
            db = (1 / num_samples) * np.sum(y_pred - y)

            self.weights = self.weights - self.lr * dw
            self.bias = self.bias - self.lr * db

        return self
    
    def predict(self, X):
        return np.dot(X, self.weights) + self.bias
    

my_regressor = Linear_regression()
my_regressor.fit(X_train, y_train)

y_pred = my_regressor.predict(X_test)

evaluate(y_test, y_pred)

X_full = np.concatenate((X_train, X_test))
y_pred_line = my_regressor.predict(X_full)

plt.figure(figsize=(10, 6))

plt.scatter(X_train, y_train, color='blue', label='Training Data', marker='o')
plt.scatter(X_test, y_test, color='red', label='Testing Data', marker='x')
plt.plot(X_full, y_pred_line, color='green', linewidth=2, label='Regression Line')

plt.xlabel("Feature X")
plt.ylabel("Target y")
plt.legend()
plt.grid(True)
# Out:
# Mean Squared Error on Test Set: 371.85
# R-squared (R^2) on Test Set: 0.92

# %%
X, y = datasets.make_regression(
        n_samples=500, n_features=10, noise=20, random_state=42)

X_train, y_train = X[:450], y[:450]
X_test, y_test = X[450:], y[450:]

my_regressor = Linear_regression()
my_regressor.fit(X_train, y_train)

y_pred = my_regressor.predict(X_test)

evaluate(y_test, y_pred)

X_full = np.concatenate((X_train, X_test))
y_pred_line = my_regressor.predict(X_full)
# Out:
# Mean Squared Error on Test Set: 553.28
# R-squared (R^2) on Test Set: 0.98
